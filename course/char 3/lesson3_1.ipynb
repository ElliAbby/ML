# %% [markdown]
# # Логистическая регрессия. Вероятностный взгляд на МО

# %% [markdown]
# ## Задача 1:
# Пусть в задаче логистической регрессии была обучена линейная модель вида:
#
# $a(x)=w^T⋅x$
#
# и был получен некоторый вектор параметров w. При этом известно, что модель a(x) для метки класса y=−1 и вектора признаков:
#
# $x=[1,190,70,1,300]^T$
#
# дает отступ (margin) равный 1.
#
# Вычислите любой вариант такого вектора w и сохраните в виде списка (или кортежа) в переменной w.

# %%
import numpy as np

def a(w, x):
    return w @ x

X = np.array([1, 190, 70, 1, 300]) 
y = -1
M = 1
w = np.zeros(len(X))
# Out:
# [0. 0. 0. 0. 0.]

# %% [markdown]
# ## Задача 2:
# Пусть в задаче логистической регрессии была обучена линейная модель вида:
#
# $a(x)=w^T⋅x$
#
# и был получен следующий вектор параметров w:
#
# $w=[20,−1,3,5,−0.15]^T$
#
# Вычислите любой вариант вектора x, для которого модель a(x) с меткой класса y=+1 дает вероятность 0,5.
#
# Сохраните вычисленный вектор x в виде списка (или кортежа) в переменной x.

# %%
import numpy as np

# здесь записывайте вектор
w = np.array([20, -1, 3, 5, -0.15])
y = 1
p = 0.5

M = -np.log(1/p - 1)

x = 1/w

x *= M / (w * y)
print(x)
# Out:
# [-0. -0. -0. -0. -0.]
